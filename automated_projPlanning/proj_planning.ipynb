# %%
from dotenv import load_dotenv
load_dotenv()
import os
import yaml
from crewai import Agent, Task, Crew,LLM
ollama_llm = LLM(
            model="ollama/llama3.2:latest",
            api_base="http://localhost:11434"
            )

# %% [markdown]
# ### read configs

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ### Creating Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent'],
  llm =  ollama_llm,
)

estimation_agent = Agent(
  config=agents_config['estimation_agent'],
  llm =  ollama_llm,
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent'],
  llm =  ollama_llm,
)

# %%
# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# %%
# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# ### Crew's Input

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ### Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# Your final answer will be a comprehensive list of tasks with detailed descriptions, timelines, dependencies, and deliverables for the Website project. It will also include a Gantt chart visualization specific to the Website project.
#
# **Task Breakdown and Timeline**
#
# 1. **Create a responsive design that works well on desktop and mobile devices**
# 	* Scope: Design a layout that adapts to different screen sizes and devices
# 	* Timeline: Week 1-2, 8 hours/day
# 	* Dependencies: None
# 	* Deliverables: Responsive design mockups (2 iterations)
# 2. **Implement a modern, visually appealing user interface with a clean look**
# 	* Scope: Develop a UI that aligns with the company's brand and style
# 	* Timeline: Week 3-4, 8 hours/day
# 	* Dependencies: Responsive design mockups
# 	* Deliverables: User interface design files (HTML, CSS, JavaScript)
# 3. **Develop a user-friendly navigation system with intuitive menu structure**
# 	* Scope: Design a menu that is easy to navigate and use on both desktop and mobile devices
# 	* Timeline: Week 5-6, 8 hours/day
# 	* Dependencies: User interface design files
# 	* Deliverables: Navigation menu prototype (2 iterations)
# 4. **Include an "About Us" page highlighting the company's history and values**
# 	* Scope: Write engaging content about the company's mission and vision
# 	* Timeline: Week 7-8, 8 hours/day
# 	* Dependencies: User interface design files
# 	* Deliverables: About Us page content (2 iterations)
# 5. **Design a "Services" page showcasing the business's offerings with descriptions**
# 	* Scope: Create a page that highlights the company's services and expertise
# 	* Timeline: Week 9-10, 8 hours/day
# 	* Dependencies: User interface design files
# 	* Deliverables: Services page content (2 iterations)
# 6. **Create a "Contact Us" page with a form and integrated map for communication**
# 	* Scope: Develop a contact form that sends emails to the company's email address
# 	* Timeline: Week 11-12, 8 hours/day
# 	* Dependencies: User interface design files
# 	* Deliverables: Contact Us page content (2 iterations)
# 7. **Implement a blog section for sharing industry news and company updates**
# 	* Scope: Design a blog that allows users to post and comment on articles
# 	* Timeline: Week 13-14, 8 hours/day
# 	* Dependencies: User interface design files
# 	* Deliverables: Blog prototype (2 iterations)
# 8. **Ensure fast loading times and optimize for search engines (SEO)**
# 	* Scope: Improve page speed and optimize meta tags for SEO
# 	* Timeline: Week 15-16, 8 hours/day
# 	* Dependencies: All previous tasks
# 	* Deliverables: Optimized website files (HTML, CSS, JavaScript)
# 9. **Integrate social media links and sharing capabilities**
# 	* Scope: Add social media links to the website's footer and allow users to share content on their profiles
# 	* Timeline: Week 17-18, 8 hours/day
# 	* Dependencies: Optimized website files
# 	* Deliverables: Social media integration prototype (2 iterations)
# 10. **Include a testimonials section to showcase customer feedback and build trust**
# 	* Scope: Gather customer testimonials and display them on the website
# 	* Timeline: Week 19-20, 8 hours/day
# 	* Dependencies: All previous tasks
# 	* Deliverables: Testimonials section content (2 iterations)
#
# **Gantt Chart**
#
# | Task | Start Date | End Date | Duration |
# | --- | --- | --- | --- |
# | Create responsive design | 2023-02-01 | 2023-02-08 | 8 days |
# | Implement modern UI | 2023-02-09 | 2023-02-16 | 7 days |
# | Develop navigation menu | 2023-02-17 | 2023-02-24 | 7 days |
# | About Us page content | 2023-03-01 | 2023-03-08 | 7 days |
# | Services page content | 2023-03-09 | 2023-03-16 | 7 days |
# | Contact Us page form | 2023-03-17 | 2023-03-24 | 7 days |
# | Blog prototype | 2023-04-01 | 2023-04-08 | 7 days |
# | Optimize website for SEO | 2023-04-09 | 2023-04-16 | 7 days |
# | Social media integration | 2023-04-17 | 2023-04-24 | 7 days |
# | Testimonials section content | 2023-05-01 | 2023-05-08 | 7 days |
#
# Note: The Gantt chart is a simplified representation of the project timeline and may not include all dependencies and tasks.
#
# **Team Assignments**
#
# * John Doe (Project Manager): Oversee the project, ensure timely completion, and coordinate with team members.
# * Jane Doe (Software Engineer): Develop the website's backend functionality, including database integration and API connectivity.
# * Bob Smith (Designer): Design the website's user interface, including responsive design, UI components, and visual elements.
# * Alice Johnson (QA Engineer): Test the website's functionality, identify bugs, and provide feedback to the development team.
# * Tom Brown (QA Engineer): Continue testing the website's functionality and ensure that all features are working as expected.
#
# This comprehensive task breakdown ensures that every aspect of the website is considered, from design to functionality and content. The Gantt chart provides a visual representation of the project timeline, helping to identify potential bottlenecks and dependencies. By assigning specific tasks to each team member, the project can be managed effectively, ensuring timely completion and high-quality deliverables.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# **Task Breakdown and Timeline**
#
# 1. **Create a responsive design that works well on desktop and mobile devices**
# 	* Scope: Design a layout that adapts to different screen sizes and devices
# 	* Timeline: Week 1-2, 8 hours/day (15 days)
# 	* Dependencies: None
# 	* Deliverables: Responsive design mockups (2 iterations) - $3000
# 2. **Implement a modern, visually appealing user interface with a clean look**
# 	* Scope: Develop a UI that aligns with the company's brand and style
# 	* Timeline: Week 3-4, 8 hours/day (16 days)
# 	* Dependencies: Responsive design mockups
# 	* Deliverables: User interface design files (HTML, CSS, JavaScript) - $4000
# 3. **Develop a user-friendly navigation system with intuitive menu structure**
# 	* Scope: Design a menu that is easy to navigate and use on both desktop and mobile devices
# 	* Timeline: Week 5-6, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: Navigation menu prototype (2 iterations) - $3500
# 4. **Include an "About Us" page highlighting the company's history and values**
# 	* Scope: Write engaging content about the company's mission and vision
# 	* Timeline: Week 7-8, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: About Us page content (2 iterations) - $2500
# 5. **Design a "Services" page showcasing the business's offerings with descriptions**
# 	* Scope: Create a page that highlights the company's services and expertise
# 	* Timeline: Week 9-10, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: Services page content (2 iterations) - $3000
# 6. **Create a "Contact Us" page with a form and integrated map for communication**
# 	* Scope: Develop a contact form that sends emails to the company's email address
# 	* Timeline: Week 11-12, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: Contact Us page content (2 iterations) - $2500
# 7. **Blog prototype**
# 	* Scope: Design a blog layout that integrates with the website's UI and backend functionality
# 	* Timeline: Week 13-14, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: Blog prototype - $3500
# 8. **Optimize website for SEO**
# 	* Scope: Conduct keyword research, optimize on-page elements, and implement meta tags and descriptions
# 	* Timeline: Week 15-16, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: Optimized website - $3000
# 9. **Social media integration**
# 	* Scope: Integrate social media feeds into the website's UI and create a social media dashboard for content management
# 	* Timeline: Week 17-18, 8 hours/day (16 days)
# 	* Dependencies: User interface design files
# 	* Deliverables: Social media integration - $3500
# 10. **Testimonials section content**
# 	* Scope: Write engaging testimonials that highlight the company's services and expertise
# 	* Timeline: Week 19-20, 8 hours/day (16 days)
# 	* Dependencies: All previous tasks
# 	* Deliverables: Testimonials section content (2 iterations) - $2500
#
# **Gantt Chart**
#
# | Task | Start Date | End Date | Duration |
# | --- | --- | --- | --- |
# | Create responsive design | 2023-02-01 | 2023-02-08 | 15 days |
# | Implement modern UI | 2023-02-09 | 2023-02-16 | 7 days |
# | Develop navigation menu | 2023-02-17 | 2023-02-24 | 7 days |
# | About Us page content | 2023-03-01 | 2023-03-08 | 7 days |
# | Services page content | 2023-03-09 | 2023-03-16 | 7 days |
# | Contact Us page form | 2023-03-17 | 2023-03-24 | 7 days |
# | Blog prototype | 2023-04-01 | 2023-04-08 | 7 days |
# | Optimize website for SEO | 2023-04-09 | 2023-04-16 | 7 days |
# | Social media integration | 2023-04-17 | 2023-04-24 | 7 days |
# | Testimonials section content | 2023-05-01 | 2023-05-08 | 7 days |
#
# **Team Assignments**
#
# * John Doe (Project Manager): Oversee the project, ensure timely completion, and coordinate with team members. ($6000)
# * Jane Doe (Software Engineer): Develop the website's backend functionality, including database integration and API connectivity. ($8000)
# * Bob Smith (Designer): Design the website's user interface, including responsive design, UI components, and visual elements. ($12,000)
# * Alice Johnson (QA Engineer): Test the website's functionality, identify bugs, and provide feedback to the development team. ($6000)
# * Tom Brown (QA Engineer): Continue testing the website's functionality and ensure that all features are working as expected. ($6000)
#
# **Total Project Cost:** $61,000
#
# **Timeline:** Week 1-20 (20 weeks)
#
# Note: The total project cost includes all tasks, team members, and dependencies. The timeline is based on a 12-week work schedule with two days of work per week.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# The project cost is $61,000 and the timeline is 20 weeks.
# ```
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/retry.py:178, in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     172                 kwargs = handle_reask_kwargs(
#     173                     kwargs=kwargs,
#     174                     mode=mode,
#     175                     response=response,
#     176                     exception=e,
#     177                 )
# --> 178                 raise e
#     179 except RetryError as e:
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/retry.py:161, in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     158     response = update_total_usage(
#     159         response=response, total_usage=total_usage
#     160     )
# --> 161     return process_response(  # type: ignore
#     162         response=response,
#     163         response_model=response_model,
#     164         validation_context=context,
#     165         strict=strict,
#     166         mode=mode,
#     167         stream=kwargs.get("stream", False),
#     168     )
#     169 except (ValidationError, JSONDecodeError) as e:
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/process_response.py:164, in process_response(response, response_model, stream, validation_context, strict, mode)
#     162     return model
# --> 164 model = response_model.from_response(
#     165     response,
#     166     validation_context=validation_context,
#     167     strict=strict,
#     168     mode=mode,
#     169 )
#     171 # ? This really hints at the fact that we need a better way of
#     172 # ? attaching usage data and the raw response to the model we return.
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/function_calls.py:156, in OpenAISchema.from_response(cls, completion, validation_context, strict, mode)
#     149 if mode in {
#     150     Mode.TOOLS,
#     151     Mode.MISTRAL_TOOLS,
#    (...)
#     154     Mode.FIREWORKS_TOOLS,
#     155 }:
# --> 156     return cls.parse_tools(completion, validation_context, strict)
#     158 if mode in {
#     159     Mode.JSON,
#     160     Mode.JSON_SCHEMA,
#    (...)
#     164     Mode.FIREWORKS_JSON,
#     165 }:
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/function_calls.py:368, in OpenAISchema.parse_tools(cls, completion, validation_context, strict)
#     365 assert (
#     366     tool_call.function.name == cls.openai_schema["name"]  # type: ignore[index]
#     367 ), "Tool name does not match"
# --> 368 return cls.model_validate_json(
#     369     tool_call.function.arguments,  # type: ignore
#     370     context=validation_context,
#     371     strict=strict,
#     372 )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/pydantic/main.py:656, in BaseModel.model_validate_json(cls, json_data, strict, context)
#     655 __tracebackhide__ = True
# --> 656 return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
#
# ValidationError: 2 validation errors for ProjectPlan
# tasks
#   Field required [type=missing, input_value={'cost': 61000, 'timeline': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# milestones
#   Field required [type=missing, input_value={'cost': 61000, 'timeline': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/retry.py:151, in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     150 response = None
# --> 151 for attempt in max_retries:
#     152     with attempt:
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/tenacity/__init__.py:443, in BaseRetrying.__iter__(self)
#     442 while True:
# --> 443     do = self.iter(retry_state=retry_state)
#     444     if isinstance(do, DoAttempt):
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/tenacity/__init__.py:419, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418     raise retry_exc.reraise()
# --> 419 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x327a62680 state=finished raised ValidationError>]
#
# The above exception was the direct cause of the following exception:
#
# InstructorRetryException                  Traceback (most recent call last)
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:27, in Converter.to_pydantic(self, current_attempt)
#      26 if self.llm.supports_function_calling():
# ---> 27     return self._create_instructor().to_pydantic()
#      28 else:
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/internal_instructor.py:40, in InternalInstructor.to_pydantic(self)
#      39 messages = [{"role": "user", "content": self.content}]
# ---> 40 model = self._client.chat.completions.create(
#      41     model=self.llm.model, response_model=self.model, messages=messages
#      42 )
#      43 return model
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/client.py:176, in Instructor.create(self, response_model, messages, max_retries, validation_context, context, strict, **kwargs)
#     174 kwargs = self.handle_kwargs(kwargs)
# --> 176 return self.create_fn(
#     177     response_model=response_model,
#     178     messages=messages,
#     179     max_retries=max_retries,
#     180     validation_context=validation_context,
#     181     context=context,
#     182     strict=strict,
#     183     hooks=self.hooks,
#     184     **kwargs,
#     185 )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/patch.py:193, in patch.<locals>.new_create_sync(response_model, validation_context, context, max_retries, strict, hooks, *args, **kwargs)
#     191 new_kwargs = handle_templating(new_kwargs, context)
# --> 193 response = retry_sync(
#     194     func=func,  # type: ignore
#     195     response_model=response_model,
#     196     context=context,
#     197     max_retries=max_retries,
#     198     args=args,
#     199     hooks=hooks,
#     200     strict=strict,
#     201     kwargs=new_kwargs,
#     202     mode=mode,
#     203 )
#     204 return response
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/instructor/retry.py:181, in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     180 logger.debug(f"Retry error: {e}")
# --> 181 raise InstructorRetryException(
#     182     e.last_attempt._exception,
#     183     last_completion=response,
#     184     n_attempts=attempt.retry_state.attempt_number,
#     185     #! deprecate messages soon
#     186     messages=kwargs.get(
#     187         "messages", kwargs.get("contents", kwargs.get("chat_history", []))
#     188     ),
#     189     create_kwargs=kwargs,
#     190     total_usage=total_usage,
#     191 ) from e
#
# InstructorRetryException: 2 validation errors for ProjectPlan
# tasks
#   Field required [type=missing, input_value={'cost': 61000, 'timeline': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# milestones
#   Field required [type=missing, input_value={'cost': 61000, 'timeline': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# During handling of the above exception, another exception occurred:
#
# ConverterError                            Traceback (most recent call last)
# Cell In[63], line 11
#       2 inputs = {
#       3   'project_type': project,
#       4   'project_objectives': project_objectives,
#    (...)
#       7   'project_requirements': project_requirements
#       8 }
#      10 # Run the crew
# ---> 11 result = crew.kickoff(
#      12   inputs=inputs
#      13 )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/crew.py:576, in Crew.kickoff(self, inputs)
#     573 metrics: List[UsageMetrics] = []
#     575 if self.process == Process.sequential:
# --> 576     result = self._run_sequential_process()
#     577 elif self.process == Process.hierarchical:
#     578     result = self._run_hierarchical_process()
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/crew.py:683, in Crew._run_sequential_process(self)
#     681 def _run_sequential_process(self) -> CrewOutput:
#     682     """Executes tasks sequentially and returns the final output."""
# --> 683     return self._execute_tasks(self.tasks)
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/crew.py:781, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     778     futures.clear()
#     780 context = self._get_context(task, task_outputs)
# --> 781 task_output = task.execute_sync(
#     782     agent=agent_to_use,
#     783     context=context,
#     784     tools=tools_for_task,
#     785 )
#     786 task_outputs.append(task_output)
#     787 self._process_task_result(task, task_output)
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/task.py:302, in Task.execute_sync(self, agent, context, tools)
#     295 def execute_sync(
#     296     self,
#     297     agent: Optional[BaseAgent] = None,
#     298     context: Optional[str] = None,
#     299     tools: Optional[List[BaseTool]] = None,
#     300 ) -> TaskOutput:
#     301     """Execute the task synchronously."""
# --> 302     return self._execute_core(agent, context, tools)
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/task.py:372, in Task._execute_core(self, agent, context, tools)
#     364 self.processed_by_agents.add(agent.role)
#     366 result = agent.execute_task(
#     367     task=self,
#     368     context=context,
#     369     tools=tools,
#     370 )
# --> 372 pydantic_output, json_output = self._export_output(result)
#     373 task_output = TaskOutput(
#     374     name=self.name,
#     375     description=self.description,
#    (...)
#     381     output_format=self._get_output_format(),
#     382 )
#     384 if self.guardrail:
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/task.py:650, in Task._export_output(self, result)
#     647 json_output: Optional[Dict[str, Any]] = None
#     649 if self.output_pydantic or self.output_json:
# --> 650     model_output = convert_to_model(
#     651         result,
#     652         self.output_pydantic,
#     653         self.output_json,
#     654         self.agent,
#     655         self.converter_cls,
#     656     )
#     658     if isinstance(model_output, BaseModel):
#     659         pydantic_output = model_output
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:109, in convert_to_model(result, output_pydantic, output_json, agent, converter_cls)
#     107     return validate_model(escaped_result, model, bool(output_json))
#     108 except json.JSONDecodeError:
# --> 109     return handle_partial_json(
#     110         result, model, bool(output_json), agent, converter_cls
#     111     )
#     113 except ValidationError:
#     114     return handle_partial_json(
#     115         result, model, bool(output_json), agent, converter_cls
#     116     )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:159, in handle_partial_json(result, model, is_json_output, agent, converter_cls)
#     153     except Exception as e:
#     154         Printer().print(
#     155             content=f"Unexpected error during partial JSON handling: {type(e).__name__}: {e}. Attempting alternative conversion method.",
#     156             color="red",
#     157         )
# --> 159 return convert_with_instructions(
#     160     result, model, is_json_output, agent, converter_cls
#     161 )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:182, in convert_with_instructions(result, model, is_json_output, agent, converter_cls)
#     172 instructions = get_conversion_instructions(model, llm)
#     173 converter = create_converter(
#     174     agent=agent,
#     175     converter_cls=converter_cls,
#    (...)
#     179     instructions=instructions,
#     180 )
#     181 exported_result = (
# --> 182     converter.to_pydantic() if not is_json_output else converter.to_json()
#     183 )
#     185 if isinstance(exported_result, ConverterError):
#     186     Printer().print(
#     187         content=f"{exported_result.message} Using raw output instead.",
#     188         color="red",
#     189     )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:44, in Converter.to_pydantic(self, current_attempt)
#      42 except Exception as e:
#      43     if current_attempt < self.max_attempts:
# ---> 44         return self.to_pydantic(current_attempt + 1)
#      45     raise ConverterError(
#      46         f"Failed to convert text into a Pydantic model due to the following error: {e}"
#      47     )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:44, in Converter.to_pydantic(self, current_attempt)
#      42 except Exception as e:
#      43     if current_attempt < self.max_attempts:
# ---> 44         return self.to_pydantic(current_attempt + 1)
#      45     raise ConverterError(
#      46         f"Failed to convert text into a Pydantic model due to the following error: {e}"
#      47     )
#
# File ~/.local/share/virtualenvs/multiagent-using-multimodal-mViAUUHF/lib/python3.10/site-packages/crewai/utilities/converter.py:45, in Converter.to_pydantic(self, current_attempt)
#      43 if current_attempt < self.max_attempts:
#      44     return self.to_pydantic(current_attempt + 1)
# ---> 45 raise ConverterError(
#      46     f"Failed to convert text into a Pydantic model due to the following error: {e}"
#      47 )
#
# ConverterError: Failed to convert text into a Pydantic model due to the following error: 2 validation errors for ProjectPlan
# tasks
#   Field required [type=missing, input_value={'cost': 61000, 'timeline': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# milestones
#   Field required [type=missing, input_value={'cost': 61000, 'timeline': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing

# %% [markdown]
# ### Usage Metrics and Costs

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0019
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0         12731           8688                     0               4043
#
#    successful_requests
# 0                    5

# %% [markdown]
# ### Result

# %%
print(result.raw)
# Out:
# The final answer is:
#
# 1. **Define Project Scope**: The project begins by defining the scope of work, including the objectives, deliverables, and timelines for each task.
# 2. **Task 2 (Responsive Design Concept)**: Develop a responsive design concept that meets the client's requirements, considering factors like user experience, accessibility, and search engine optimization.
# 3. **Task 3 (User Interface Mockups)**: Create user interface mockups for the website, ensuring consistency with the design concept and meeting the client's expectations.
# 4. **Task 4 (Navigation System)**: Design a navigation system that is intuitive, efficient, and aligns with the overall user experience strategy.
# 5. **Task 5 (About Us Page Content)**: Develop engaging content for the About Us page, highlighting the company's mission, values, and accomplishments.
# 6. **Task 6 (Services Page Content)**: Create compelling content for the Services page, showcasing the range of services offered and their benefits to clients.
# 7. **Task 7 (Contact Form)**: Implement a contact form that allows users to easily get in touch with the company, ensuring timely responses and effective communication.
# 8. **Task 8 (Blog Section)**: Develop a blog section that publishes regular articles on topics relevant to the industry, establishing the company as a thought leader.
# 9. **Task 9 (SEO Optimization)**: Conduct thorough SEO optimization for the website, including keyword research, meta tags, header tags, and internal linking.
# 10. **Task 10 (Social Media Integration)**: Integrate social media platforms into the website, allowing users to easily share content and connect with the company's online presence.
# 11. **Task 11 (Testimonials Section)**: Create a testimonials section that showcases client success stories, demonstrating the value of the company's services.
# 12. **Task 12 (Final Website Design and Development)**: Review and finalize all website design and development tasks, ensuring complete accuracy and alignment with project requirements.
# 13. **Task 13 (Deployment to Production Environment)**: Deploy the website to a production environment, configuring servers, databases, and other necessary infrastructure.
# 14. **Task 14 (Launch and Promotional Strategy)**: Launch the website, develop a promotional strategy, and execute it across social media channels, email marketing, and content marketing.
#
# By following this project plan, the team should be able to deliver a high-quality website that meets the client's expectations and provides an excellent user experience.

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 tasks = result.pydantic.dict()['tasks']
#       2 df_tasks = pd.DataFrame(tasks)
#       4 # Display the DataFrame as an HTML table
#
# AttributeError: 'NoneType' object has no attribute 'dict'

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 milestones = result.pydantic.dict()['milestones']
#       2 df_milestones = pd.DataFrame(milestones)
#       4 # Display the DataFrame as an HTML table
#
# AttributeError: 'NoneType' object has no attribute 'dict'
