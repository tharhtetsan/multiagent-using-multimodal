# %%
from dotenv import load_dotenv
load_dotenv()
import os
import yaml
from crewai import Agent, Task, Crew,LLM
ollama_llm = LLM(
            model="ollama/llama3.2:latest",
            api_base="http://localhost:11434"
            )

# %% [markdown]
# ### read configs

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ### Creating Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent'],
  llm =  ollama_llm,
)

estimation_agent = Agent(
  config=agents_config['estimation_agent'],
  llm =  ollama_llm,
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent'],
  llm =  ollama_llm,
)

# %%
# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# %%
# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# ### Crew's Input

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ### Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Task Breakdown for Website Project**
#
# ### Task 1: Define Project Scope and Requirements (Deadline: Day 1)
#
# * Task Owner: John Doe
# * Description:
# 	+ Review project requirements documents
# 	+ Conduct a thorough analysis of the website's functionality, features, and design elements
# 	+ Identify potential risks, assumptions, and dependencies
# 	+ Create a detailed project scope statement outlining deliverables, timelines, and resources required
# * Dependencies: N/A
# * Deliverable: Project Scope Statement (docx)
#
# ### Task 2: Develop Responsive Design Concept (Deadline: Day 5)
#
# * Task Owner: Bob Smith
# * Description:
# 	+ Create a responsive design concept using Sketch or Figma
# 	+ Ensure the design is optimized for desktop, tablet, and mobile devices
# 	+ Present the design concept to the team for feedback and approval
# * Dependencies: Task 1 (Project Scope Statement)
# * Deliverable: Responsive Design Concept Document (pdf)
#
# ### Task 3: Create User Interface Mockups (Deadline: Day 10)
#
# * Task Owner: Bob Smith
# * Description:
# 	+ Create high-fidelity user interface mockups using Sketch or Figma
# 	+ Ensure the design is visually appealing and consistent with the brand guidelines
# 	+ Present the UI mockups to the team for feedback and approval
# * Dependencies: Task 2 (Responsive Design Concept)
# * Deliverable: User Interface Mockups Document (pdf)
#
# ### Task 4: Develop Navigation System (Deadline: Day 15)
#
# * Task Owner: Jane Doe
# * Description:
# 	+ Create a user-friendly navigation system with an intuitive menu structure
# 	+ Ensure the navigation system is responsive and works well on desktop, tablet, and mobile devices
# 	+ Integrate with the responsive design concept
# * Dependencies: Tasks 2 and 3 (Responsive Design Concept and User Interface Mockups)
# * Deliverable: Navigation System Code (php/HTML/CSS)
#
# ### Task 5: Create "About Us" Page Content (Deadline: Day 20)
#
# * Task Owner: Alice Johnson
# * Description:
# 	+ Write high-quality content for the "About Us" page
# 	+ Ensure the content is engaging, informative, and consistent with the brand tone
# 	+ Review and approve content with John Doe
# * Dependencies: N/A
# * Deliverable: "About Us" Page Content Document (docx)
#
# ### Task 6: Create "Services" Page Content (Deadline: Day 25)
#
# * Task Owner: Alice Johnson
# * Description:
# 	+ Write high-quality content for the "Services" page
# 	+ Ensure the content is descriptive, informative, and consistent with the brand tone
# 	+ Review and approve content with John Doe
# * Dependencies: N/A
# * Deliverable: "Services" Page Content Document (docx)
#
# ### Task 7: Create "Contact Us" Page Form (Deadline: Day 30)
#
# * Task Owner: Jane Doe
# * Description:
# 	+ Design a contact form that integrates with the navigation system
# 	+ Ensure the form is user-friendly, secure, and meets accessibility standards
# 	+ Integrate with Google Maps API for location-based searching
# * Dependencies: Tasks 4 (Navigation System) and 5 (About Us Page Content)
# * Deliverable: Contact Form Code (php/HTML/CSS)
#
# ### Task 8: Implement Blog Section (Deadline: Day 35)
#
# * Task Owner: Jane Doe
# * Description:
# 	+ Create a blog section for sharing industry news and company updates
# 	+ Ensure the blog is responsive, user-friendly, and integrates with the navigation system
# 	+ Use a content management system (CMS) for easy content creation and publishing
# * Dependencies: Tasks 4 (Navigation System), 5 (About Us Page Content), and 6 (Services Page Content)
# * Deliverable: Blog Section Code (php/HTML/CSS)
#
# ### Task 9: Optimize Website for SEO (Deadline: Day 40)
#
# * Task Owner: John Doe
# * Description:
# 	+ Conduct keyword research and analysis to identify relevant keywords
# 	+ Optimize website content, meta tags, titles, and descriptions with target keywords
# 	+ Use header tags (H1-H6), subheadings, and descriptive alt text for images
# * Dependencies: Tasks 2-8 (Responsive Design Concept, User Interface Mockups, Navigation System, About Us Page Content, Services Page Content, Contact Form)
# * Deliverable: SEO Optimization Document (pdf)
#
# ### Task 10: Integrate Social Media Links and Sharing Capabilities (Deadline: Day 45)
#
# * Task Owner: Jane Doe
# * Description:
# 	+ Create social media links and buttons for integration with the website
# 	+ Implement sharing capabilities using JavaScript and CSS
# 	+ Ensure the sharing functionality works across multiple platforms
# * Dependencies: Tasks 2-9 (Responsive Design Concept, User Interface Mockups, Navigation System, About Us Page Content, Services Page Content, Contact Form, SEO Optimization)
# * Deliverable: Social Media Links Code (HTML/CSS)
#
# ### Task 11: Create Testimonials Section (Deadline: Day 50)
#
# * Task Owner: Alice Johnson
# * Description:
# 	+ Collect and curate testimonials from satisfied customers
# 	+ Write engaging content for the testimonials section
# 	+ Ensure the design is visually appealing and consistent with the brand guidelines
# * Dependencies: N/A
# * Deliverable: Testimonials Section Content Document (docx)
#
# ### Task 12: Finalize Website Design and Development (Deadline: Day 55)
#
# * Task Owner: John Doe
# * Description:
# 	+ Review and finalize all website design and development tasks
# 	+ Conduct a thorough quality assurance test to ensure the website meets project requirements
# 	+ Make any necessary adjustments or fixes before deployment
# * Dependencies: Tasks 1-11 (Project Scope Statement, Responsive Design Concept, User Interface Mockups, Navigation System, About Us Page Content, Services Page Content, Contact Form, Blog Section, SEO Optimization, Social Media Links, Testimonials Section)
# * Deliverable: Final Website Design and Development
#
# ### Task 13: Deploy Website to Production Environment (Deadline: Day 60)
#
# * Task Owner: John Doe
# * Description:
# 	+ Prepare the website for deployment to a production environment
# 	+ Conduct a final quality assurance test to ensure the website is functional and meets project requirements
# 	+ Make any necessary adjustments or fixes before deployment
# * Dependencies: Tasks 1-12 (Project Scope Statement, Responsive Design Concept, User Interface Mockups, Navigation System, About Us Page Content, Services Page Content, Contact Form, Blog Section, SEO Optimization, Social Media Links, Testimonials Section)
# * Deliverable: Deployed Website
#
# ### Task 14: Launch and Promote Website (Deadline: Day 65)
#
# * Task Owner: John Doe
# * Description:
# 	+ Launch the website to the public and make it available for viewing
# 	+ Develop a marketing strategy to promote the website across social media channels, email marketing, and content marketing
# 	+ Monitor website analytics and track key performance indicators (KPIs) to measure success
# * Dependencies: Task 13 (Deployed Website)
# * Deliverable: Launched Website with Promotional Strategy
#
# Gantt Chart:
# ```
# +---------------------------+
# |         Day 1          |
# +---------------------------+
# |  Define Project Scope  |
# +---------------------------+
# |
# |    +---------------+      +---------------+      +---------------+       |
# |    | Task 2        |     | Task 3        |     | Task 4        |       |
# |    +---------------+     +---------------+     +---------------+       |
# |           |                |                        |                     |
# |           |                |  +---------------+      +---------------+       |
# |           |                |  | Task 5        |      | Task 6        |       |
# |           |                |  +---------------+      +---------------+       |
# |           |                |          |                      |                     |
# |           |                |          |     +---------------+      +---------------+       |
# |           |                |          |     | Task 7        |      | Task 8        |       |
# |           |                |          |  +---------------+      +---------------+       |
# |           |                |          |          |                      |                     |
# |           |                |          |          |     +---------------+      +---------------+       |
# |           |                |          |          |     | Task 9        |      | Task 10       |
# |           |                |          |          |  +---------------+      +---------------+       |
# |           |                |          |          |                       |                     |
# |           |                |          |          |     +---------------+      +---------------+       |
# |           |                |          |          |     | Task 11        |      | Task 12       |
# |           |                |          |          |  +---------------+      +---------------+       |
# |           |                |          |          |                       |                     |
# |           |                |          |          |     +---------------+      +---------------+       |
# |           |                |          |          |     | Task 13        |      | Task 14       |
# |           |                |          |          |  +---------------+      +---------------+       |
# +---------------------------+
# ```
# Note: The Gantt chart shows the sequence of tasks and dependencies between them. Tasks are represented as boxes, while arrows indicate the relationships between tasks.
#
# This project plan assumes a fixed timeline of 65 days, with each task representing a specific milestone or deliverable. The Gantt chart provides a visual representation of the project schedule, highlighting dependencies and critical path activities.
#
# Please note that this is just an example project plan, and actual projects may require more detailed planning, adjustments, and revisions based on changing requirements, resource availability, and other factors.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# The final answer is:
#
# 1. **Define Project Scope**: The project begins by defining the scope of work, including the objectives, deliverables, and timelines for each task.
# 2. **Task 2 (Responsive Design Concept)**: Develop a responsive design concept that meets the client's requirements, considering factors like user experience, accessibility, and search engine optimization.
# 3. **Task 3 (User Interface Mockups)**: Create user interface mockups for the website, ensuring consistency with the design concept and meeting the client's expectations.
# 4. **Task 4 (Navigation System)**: Design a navigation system that is intuitive, efficient, and aligns with the overall user experience strategy.
# 5. **Task 5 (About Us Page Content)**: Develop engaging content for the About Us page, highlighting the company's mission, values, and accomplishments.
# 6. **Task 6 (Services Page Content)**: Create compelling content for the Services page, showcasing the range of services offered and their benefits to clients.
# 7. **Task 7 (Contact Form)**: Implement a contact form that allows users to easily get in touch with the company, ensuring timely responses and effective communication.
# 8. **Task 8 (Blog Section)**: Develop a blog section that publishes regular articles on topics relevant to the industry, establishing the company as a thought leader.
# 9. **Task 9 (SEO Optimization)**: Conduct thorough SEO optimization for the website, including keyword research, meta tags, header tags, and internal linking.
# 10. **Task 10 (Social Media Integration)**: Integrate social media platforms into the website, allowing users to easily share content and connect with the company's online presence.
# 11. **Task 11 (Testimonials Section)**: Create a testimonials section that showcases client success stories, demonstrating the value of the company's services.
# 12. **Task 12 (Final Website Design and Development)**: Review and finalize all website design and development tasks, ensuring complete accuracy and alignment with project requirements.
# 13. **Task 13 (Deployment to Production Environment)**: Deploy the website to a production environment, configuring servers, databases, and other necessary infrastructure.
# 14. **Task 14 (Launch and Promotional Strategy)**: Launch the website, develop a promotional strategy, and execute it across social media channels, email marketing, and content marketing.
#
# By following this project plan, the team should be able to deliver a high-quality website that meets the client's expectations and provides an excellent user experience.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# The final answer is:
#
# 1. **Define Project Scope**: The project begins by defining the scope of work, including the objectives, deliverables, and timelines for each task.
# 2. **Task 2 (Responsive Design Concept)**: Develop a responsive design concept that meets the client's requirements, considering factors like user experience, accessibility, and search engine optimization.
# 3. **Task 3 (User Interface Mockups)**: Create user interface mockups for the website, ensuring consistency with the design concept and meeting the client's expectations.
# 4. **Task 4 (Navigation System)**: Design a navigation system that is intuitive, efficient, and aligns with the overall user experience strategy.
# 5. **Task 5 (About Us Page Content)**: Develop engaging content for the About Us page, highlighting the company's mission, values, and accomplishments.
# 6. **Task 6 (Services Page Content)**: Create compelling content for the Services page, showcasing the range of services offered and their benefits to clients.
# 7. **Task 7 (Contact Form)**: Implement a contact form that allows users to easily get in touch with the company, ensuring timely responses and effective communication.
# 8. **Task 8 (Blog Section)**: Develop a blog section that publishes regular articles on topics relevant to the industry, establishing the company as a thought leader.
# 9. **Task 9 (SEO Optimization)**: Conduct thorough SEO optimization for the website, including keyword research, meta tags, header tags, and internal linking.
# 10. **Task 10 (Social Media Integration)**: Integrate social media platforms into the website, allowing users to easily share content and connect with the company's online presence.
# 11. **Task 11 (Testimonials Section)**: Create a testimonials section that showcases client success stories, demonstrating the value of the company's services.
# 12. **Task 12 (Final Website Design and Development)**: Review and finalize all website design and development tasks, ensuring complete accuracy and alignment with project requirements.
# 13. **Task 13 (Deployment to Production Environment)**: Deploy the website to a production environment, configuring servers, databases, and other necessary infrastructure.
# 14. **Task 14 (Launch and Promotional Strategy)**: Launch the website, develop a promotional strategy, and execute it across social media channels, email marketing, and content marketing.
#
# By following this project plan, the team should be able to deliver a high-quality website that meets the client's expectations and provides an excellent user experience.

# %% [markdown]
# ### Usage Metrics and Costs

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0019
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0         12731           8688                     0               4043
#
#    successful_requests
# 0                    5

# %% [markdown]
# ### Result

# %%
print(result.raw)
# Out:
# The final answer is:
#
# 1. **Define Project Scope**: The project begins by defining the scope of work, including the objectives, deliverables, and timelines for each task.
# 2. **Task 2 (Responsive Design Concept)**: Develop a responsive design concept that meets the client's requirements, considering factors like user experience, accessibility, and search engine optimization.
# 3. **Task 3 (User Interface Mockups)**: Create user interface mockups for the website, ensuring consistency with the design concept and meeting the client's expectations.
# 4. **Task 4 (Navigation System)**: Design a navigation system that is intuitive, efficient, and aligns with the overall user experience strategy.
# 5. **Task 5 (About Us Page Content)**: Develop engaging content for the About Us page, highlighting the company's mission, values, and accomplishments.
# 6. **Task 6 (Services Page Content)**: Create compelling content for the Services page, showcasing the range of services offered and their benefits to clients.
# 7. **Task 7 (Contact Form)**: Implement a contact form that allows users to easily get in touch with the company, ensuring timely responses and effective communication.
# 8. **Task 8 (Blog Section)**: Develop a blog section that publishes regular articles on topics relevant to the industry, establishing the company as a thought leader.
# 9. **Task 9 (SEO Optimization)**: Conduct thorough SEO optimization for the website, including keyword research, meta tags, header tags, and internal linking.
# 10. **Task 10 (Social Media Integration)**: Integrate social media platforms into the website, allowing users to easily share content and connect with the company's online presence.
# 11. **Task 11 (Testimonials Section)**: Create a testimonials section that showcases client success stories, demonstrating the value of the company's services.
# 12. **Task 12 (Final Website Design and Development)**: Review and finalize all website design and development tasks, ensuring complete accuracy and alignment with project requirements.
# 13. **Task 13 (Deployment to Production Environment)**: Deploy the website to a production environment, configuring servers, databases, and other necessary infrastructure.
# 14. **Task 14 (Launch and Promotional Strategy)**: Launch the website, develop a promotional strategy, and execute it across social media channels, email marketing, and content marketing.
#
# By following this project plan, the team should be able to deliver a high-quality website that meets the client's expectations and provides an excellent user experience.

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 tasks = result.pydantic.dict()['tasks']
#       2 df_tasks = pd.DataFrame(tasks)
#       4 # Display the DataFrame as an HTML table
#
# AttributeError: 'NoneType' object has no attribute 'dict'

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 milestones = result.pydantic.dict()['milestones']
#       2 df_milestones = pd.DataFrame(milestones)
#       4 # Display the DataFrame as an HTML table
#
# AttributeError: 'NoneType' object has no attribute 'dict'
